# %% [markdown]
# # [FROM HERE](https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS)
#
# # Minute 7.05
#
# # [PART 3 - Python Pandas Tutorial (Part 3): Indexes - How to Set, Reset, and Use Indexes](https://www.youtube.com/watch?v=W9XjRYFkkyw&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=5)
#
# # [Data FROM HERE => ](https://survey.stackoverflow.co/)

# %%
import pandas as pd

# %% [markdown]
# # set the index equal to data

# %%
# source link see yt video description
# df= pd.read_csv('data/survey_results_public.csv')
# add follow see Timestamp in the vid 8.46
df= pd.read_csv('data/survey_results_public.csv',index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col='qname')

# %% [markdown]
# ## set max columns and rows

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# 2           Hobby;Contribute to open-source projects
# 3                                              Hobby
# 4                       I don’t code outside of work
# 5                                              Hobby
#
#                                                     EdLevel  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Books / Physical media;Friend or family member...
# 4           Books / Physical media;School (i.e., Universit...
# 5           Other online resources (e.g., videos, blogs, f...
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Technical documentation;Blogs;Programming Game...
# 4                                                         NaN
# 5           Technical documentation;Blogs;Stack Overflow;O...
#
#            LearnCodeCoursesCert YearsCode YearsCodePro  \
# ResponseId
# 1                           NaN       NaN          NaN
# 2                           NaN       NaN          NaN
# 3                           NaN        14            5
# 4                           NaN        20           17
# 5                           NaN         8            3
#
#                                                       DevType  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Data scientist or machine learning specialist;...
# 4                                       Developer, full-stack
# 5           Developer, front-end;Developer, full-stack;Dev...
#
#                          OrgSize      PurchaseInfluence  \
# ResponseId
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3             20 to 99 employees  I have some influence
# 4           100 to 499 employees  I have some influence
# 5             20 to 99 employees  I have some influence
#
#                                                    BuyNewTool  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                     Other (please specify):
# 5           Start a free trial;Visit developer communities...
#
#                                                       Country  \
# ResponseId
# 1                                                         NaN
# 2                                                      Canada
# 3           United Kingdom of Great Britain and Northern I...
# 4                                                      Israel
# 5                                    United States of America
#
#                              Currency  CompTotal CompFreq  \
# ResponseId
# 1                                 NaN        NaN      NaN
# 2                CAD\tCanadian dollar        NaN      NaN
# 3                 GBP\tPound sterling    32000.0   Yearly
# 4             ILS\tIsraeli new shekel    60000.0  Monthly
# 5           USD\tUnited States dollar        NaN      NaN
#
#                                  LanguageHaveWorkedWith  \
# ResponseId
# 1                                                   NaN
# 2                                 JavaScript;TypeScript
# 3                     C#;C++;HTML/CSS;JavaScript;Python
# 4                          C#;JavaScript;SQL;TypeScript
# 5           C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#
#                                 LanguageWantToWorkWith  \
# ResponseId
# 1                                                  NaN
# 2                                      Rust;TypeScript
# 3                C#;C++;HTML/CSS;JavaScript;TypeScript
# 4                                    C#;SQL;TypeScript
# 5           C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                        Microsoft SQL Server
# 4                                        Microsoft SQL Server
# 5           Cloud Firestore;Elasticsearch;Microsoft SQL Se...
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                        Microsoft SQL Server
# 4                                        Microsoft SQL Server
# 5           Cloud Firestore;Elasticsearch;Firebase Realtim...
#
#               PlatformHaveWorkedWith    PlatformWantToWorkWith  \
# ResponseId
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# 5           Firebase;Microsoft Azure  Firebase;Microsoft Azure
#
#                                   WebframeHaveWorkedWith  \
# ResponseId
# 1                                                    NaN
# 2                                                    NaN
# 3                                             Angular.js
# 4                                  ASP.NET;ASP.NET Core
# 5           Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
#
#                           WebframeWantToWorkWith MiscTechHaveWorkedWith  \
# ResponseId
# 1                                            NaN                    NaN
# 2                                            NaN                    NaN
# 3                             Angular;Angular.js                 Pandas
# 4                          ASP.NET;ASP.NET Core                    .NET
# 5           Angular;ASP.NET Core ;Blazor;Node.js                   .NET
#
#            MiscTechWantToWorkWith ToolsTechHaveWorkedWith  \
# ResponseId
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                            .NET                     NaN
# 4                            .NET                     NaN
# 5               .NET;Apache Kafka                     npm
#
#            ToolsTechWantToWorkWith  \
# ResponseId
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                Docker;Kubernetes
#
#                                 NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                                        NaN
# 2                                                        NaN
# 3                                    Notepad++;Visual Studio
# 4                 Notepad++;Visual Studio;Visual Studio Code
# 5           Notepad++;Visual Studio;Visual Studio Code;Xcode
#
#                           NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# ResponseId
# 1                                                  NaN                   NaN
# 2                                                  NaN                 macOS
# 3                              Notepad++;Visual Studio               Windows
# 4           Notepad++;Visual Studio;Visual Studio Code               Windows
# 5               Rider;Visual Studio;Visual Studio Code               Windows
#
#                             OpSysPersonal use         VersionControlSystem  \
# ResponseId
# 1                                         NaN                          NaN
# 2           Windows Subsystem for Linux (WSL)                          Git
# 3                                     Windows                          Git
# 4                                     Windows                          Git
# 5                               macOS;Windows  Git;Other (please specify):
#
#                                                 VCInteraction  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                 Code editor
# 4           Code editor;Command-line;Version control hosti...
# 5                                                 Code editor
#
#             VCHostingPersonal use  VCHostingProfessional use  \
# ResponseId
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# 5                             NaN                        NaN
#
#            OfficeStackAsyncHaveWorkedWith OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4             Jira Work Management;Trello    Jira Work Management;Trello
# 5                                     NaN                            NaN
#
#            OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# ResponseId
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                        Microsoft Teams               Microsoft Teams
# 4                             Slack;Zoom                    Slack;Zoom
# 5                   Microsoft Teams;Zoom                           NaN
#
#                   Blockchain  \
# ResponseId
# 1                        NaN
# 2           Very unfavorable
# 3           Very unfavorable
# 4           Very unfavorable
# 5                Unfavorable
#
#                                                    NEWSOSites  \
# ResponseId
# 1                                                         NaN
# 2           Collectives on Stack Overflow;Stack Overflow f...
# 3           Collectives on Stack Overflow;Stack Overflow;S...
# 4           Collectives on Stack Overflow;Stack Overflow f...
# 5           Collectives on Stack Overflow;Stack Overflow f...
#
#                        SOVisitFreq SOAccount              SOPartFreq  \
# ResponseId
# 1                              NaN       NaN                     NaN
# 2            Daily or almost daily       Yes   Daily or almost daily
# 3           Multiple times per day       Yes  Multiple times per day
# 4            Daily or almost daily       Yes    A few times per week
# 5           Multiple times per day       Yes   Daily or almost daily
#
#                      SOComm              Age Gender Trans  \
# ResponseId
# 1                       NaN              NaN    NaN   NaN
# 2                  Not sure              NaN    NaN   NaN
# 3                   Neutral  25-34 years old    Man    No
# 4           Yes, definitely  35-44 years old    Man    No
# 5           Yes, definitely  25-34 years old    NaN   NaN
#
#                           Sexuality Ethnicity      Accessibility  \
# ResponseId
# 1                               NaN       NaN                NaN
# 2                               NaN       NaN                NaN
# 3                          Bisexual     White  None of the above
# 4           Straight / Heterosexual     White  None of the above
# 5                               NaN       NaN                NaN
#
#                                                  MentalHealth TBranch ICorPM  \
# ResponseId
# 1                                                         NaN     NaN    NaN
# 2                                                         NaN      No    NaN
# 3           I have a mood or emotional disorder (e.g., dep...      No    NaN
# 4                                           None of the above      No    NaN
# 5                                                         NaN      No    NaN
#
#             WorkExp Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4  \
# ResponseId
# 1               NaN         NaN         NaN         NaN         NaN
# 2               NaN         NaN         NaN         NaN         NaN
# 3               NaN         NaN         NaN         NaN         NaN
# 4               NaN         NaN         NaN         NaN         NaN
# 5               NaN         NaN         NaN         NaN         NaN
#
#            Knowledge_5 Knowledge_6 Knowledge_7 Frequency_1 Frequency_2  \
# ResponseId
# 1                  NaN         NaN         NaN         NaN         NaN
# 2                  NaN         NaN         NaN         NaN         NaN
# 3                  NaN         NaN         NaN         NaN         NaN
# 4                  NaN         NaN         NaN         NaN         NaN
# 5                  NaN         NaN         NaN         NaN         NaN
#
#            Frequency_3 TimeSearching TimeAnswering Onboarding  \
# ResponseId
# 1                  NaN           NaN           NaN        NaN
# 2                  NaN           NaN           NaN        NaN
# 3                  NaN           NaN           NaN        NaN
# 4                  NaN           NaN           NaN        NaN
# 5                  NaN           NaN           NaN        NaN
#
#            ProfessionalTech TrueFalse_1 TrueFalse_2 TrueFalse_3  \
# ResponseId
# 1                       NaN         NaN         NaN         NaN
# 2                       NaN         NaN         NaN         NaN
# 3                       NaN         NaN         NaN         NaN
# 4                       NaN         NaN         NaN         NaN
# 5                       NaN         NaN         NaN         NaN
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 1                             NaN                         NaN
# 2                        Too long                   Difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5                        Too long                        Easy
#
#             ConvertedCompYearly
# ResponseId
# 1                           NaN
# 2                           NaN
# 3                       40205.0
# 4                      215232.0
# 5                           NaN

# %% [markdown]
# ## first response

# %%
df.loc[1]
# Out:
# MainBranch                        None of these
# Employment                                  NaN
# RemoteWork                                  NaN
# CodingActivities                            NaN
# EdLevel                                     NaN
# LearnCode                                   NaN
# LearnCodeOnline                             NaN
# LearnCodeCoursesCert                        NaN
# YearsCode                                   NaN
# YearsCodePro                                NaN
# DevType                                     NaN
# OrgSize                                     NaN
# PurchaseInfluence                           NaN
# BuyNewTool                                  NaN
# Country                                     NaN
# Currency                                    NaN
# CompTotal                                   NaN
# CompFreq                                    NaN
# LanguageHaveWorkedWith                      NaN
# LanguageWantToWorkWith                      NaN
# DatabaseHaveWorkedWith                      NaN
# DatabaseWantToWorkWith                      NaN
# PlatformHaveWorkedWith                      NaN
# PlatformWantToWorkWith                      NaN
# WebframeHaveWorkedWith                      NaN
# WebframeWantToWorkWith                      NaN
# MiscTechHaveWorkedWith                      NaN
# MiscTechWantToWorkWith                      NaN
# ToolsTechHaveWorkedWith                     NaN
# ToolsTechWantToWorkWith                     NaN
# NEWCollabToolsHaveWorkedWith                NaN
# NEWCollabToolsWantToWorkWith                NaN
# OpSysProfessional use                       NaN
# OpSysPersonal use                           NaN
# VersionControlSystem                        NaN
# VCInteraction                               NaN
# VCHostingPersonal use                       NaN
# VCHostingProfessional use                   NaN
# OfficeStackAsyncHaveWorkedWith              NaN
# OfficeStackAsyncWantToWorkWith              NaN
# OfficeStackSyncHaveWorkedWith               NaN
# OfficeStackSyncWantToWorkWith               NaN
# Blockchain                                  NaN
# NEWSOSites                                  NaN
# SOVisitFreq                                 NaN
# SOAccount                                   NaN
# SOPartFreq                                  NaN
# SOComm                                      NaN
# Age                                         NaN
# Gender                                      NaN
# Trans                                       NaN
# Sexuality                                   NaN
# Ethnicity                                   NaN
# Accessibility                               NaN
# MentalHealth                                NaN
# TBranch                                     NaN
# ICorPM                                      NaN
# WorkExp                                     NaN
# Knowledge_1                                 NaN
# Knowledge_2                                 NaN
# Knowledge_3                                 NaN
# Knowledge_4                                 NaN
# Knowledge_5                                 NaN
# Knowledge_6                                 NaN
# Knowledge_7                                 NaN
# Frequency_1                                 NaN
# Frequency_2                                 NaN
# Frequency_3                                 NaN
# TimeSearching                               NaN
# TimeAnswering                               NaN
# Onboarding                                  NaN
# ProfessionalTech                            NaN
# TrueFalse_1                                 NaN
# TrueFalse_2                                 NaN
# TrueFalse_3                                 NaN
# SurveyLength                                NaN
# SurveyEase                                  NaN
# ConvertedCompYearly                         NaN
# Name: 1, dtype: object

# %% [markdown]
# # schema

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
schema_df.loc['LanguageHaveWorkedWith']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/python_try_pandas_two/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageHaveWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 schema_df.loc['LanguageHaveWorkedWith']
#
# File ~/python_try_pandas_two/.venv/lib/python3.11/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/python_try_pandas_two/.venv/lib/python3.11/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/python_try_pandas_two/.venv/lib/python3.11/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/python_try_pandas_two/.venv/lib/python3.11/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/python_try_pandas_two/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'LanguageHaveWorkedWith'
