# %% [markdown]
# # [FROM HERE](https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS)
#
# # Minute 7.05
#
# # [PART 3 - Python Pandas Tutorial (Part 3): Indexes - How to Set, Reset, and Use Indexes](https://www.youtube.com/watch?v=W9XjRYFkkyw&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=5)
#
# # [Data FROM HERE => ](https://survey.stackoverflow.co/)

# %%
import pandas as pd

# %% [markdown]
# # set the index equal to data

# %%
# source link see yt video description
# df= pd.read_csv('data/survey_results_public.csv')
# add follow see Timestamp in the vid 8.46

# set the index of index.col
df= pd.read_csv('data/survey_results_public.csv',index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col='qname')

# %% [markdown]
# ## set max columns and rows

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()

# %% [markdown]
# ## first response

# %%
df.loc[1]

# %% [markdown]
# # schema

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %% [markdown]
# # see the schema data about the row

# %%
schema_df.loc['SurveyLength']

# %% [markdown]
# # if you want see ONE columns of the row/DataFrame

# %%
schema_df.loc['SurveyLength','question']

# %% [markdown]
# # see the single column

# %%
df['RemoteWork']

# %% [markdown]
# # see index (repeat)- first column

# %%
df

# %% [markdown]
# # set the index of another columns
#
# # pass

# %% [markdown]
# # you want sort index

# %%
schema_df.sort_index(ascending=True)
# Out:
#                          qid  \
# qname
# AIAcc                 QID316
# AIBen                 QID324
# AIChallenges          QID346
# AIComplex             QID343
# AIEthics              QID339
# AINext                QID320
# AISearchDev           QID327
# AISelect              QID314
# AISent                QID315
# AIThreat              QID338
# AITool                QID319
# Age                   QID127
# BuildvsBuy            QID330
# BuyNewTool            QID279
# Check                 QID341
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Embedded              QID340
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Frustration           QID342
# ICorPM                QID287
# ...

# %% [markdown]
# # [cols and rows of data frame](https://www.freecodecamp.org/news/pandas-count-rows-how-to-get-the-number-of-rows-in-a-dataframe/)

# %%
rows_schema_df =len(schema_df) 
pd.set_option('display.max_rows',rows_schema_df)

columns_schema_df = df.shape[0]
pd.set_option('display.max_columns',columns_schema_df)

schema_df

# %% [markdown]
# # data frame permanent sorted (Vid=> 14:47) - live time long

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                 QID316
# AIBen                 QID324
# AIChallenges          QID346
# AIComplex             QID343
# AIEthics              QID339
# AINext                QID320
# AISearchDev           QID327
# AISelect              QID314
# AISent                QID315
# AIThreat              QID338
# AITool                QID319
# Age                   QID127
# BuildvsBuy            QID330
# BuyNewTool            QID279
# Check                 QID341
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Embedded              QID340
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Frustration           QID342
# ICorPM                QID287
# ...
